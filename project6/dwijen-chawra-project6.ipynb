# %% [markdown]
# # Project 6 -- Dwijen Chawra

# %% [markdown]
# ## Question 1

# %%
import requests
import bs4

response = requests.get("https://sheader.the-examples-book.com", 
    headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.16; rv:86.0) Gecko/20100101 Firefox/86.0', 
        'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
)
print(response.request.headers)
print(response.text)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.16; rv:86.0) Gecko/20100101 Firefox/86.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
# Hostname: 774be90e6f83
# IP: 127.0.0.1
# IP: 172.17.0.4
# RemoteAddr: 172.17.0.1:46992
# GET / HTTP/1.1
# Host: sheader.the-examples-book.com
# User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10.16; rv:86.0) Gecko/20100101 Firefox/86.0
# Accept: */*
# Accept-Encoding: gzip
# Cdn-Loop: cloudflare
# Cf-Connecting-Ip: 128.211.155.42
# Cf-Ipcountry: US
# Cf-Ray: 79ec7ebc4b592085-IND
# Cf-Visitor: {"scheme":"https"}
# X-Forwarded-For: 128.211.155.42
# X-Forwarded-Host: sheader.the-examples-book.com
# X-Forwarded-Proto: https
# X-Real-Ip: Mozilla/5.0 (Macintosh; Intel Mac OS X 10.16; rv:86.0) Gecko/20100101 Firefox/86.0

# %% [markdown]
# Changed the user agent and the request was successful.

# %% [markdown]
# ## Question 2

# %%
def get_ray(url, header):
    response = requests.get(url, 
        headers={'User-Agent': header, 
            'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
    )

    content = str(bs4.BeautifulSoup(response.text, 'html.parser'))

    split = content.split(': ')

    # find CF-RAY in the content
    for i in range(len(split)):
        if "Cf-Ray".lower() in split[i].lower():
            return split[i+1][:20]
    
agentlist = """Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36
Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2919.83 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2866.71 Safari/537.36
Mozilla/5.0 (X11; Ubuntu; Linux i686 on x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2820.59 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2762.73 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2656.18 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/44.0.2403.155 Safari/537.36
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36
Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2226.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.4; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2225.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2225.0 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2224.3 Safari/537.36
Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.124 Safari/537.36
Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36
Mozilla/5.0 (Windows NT 4.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36
Mozilla/5.0 (X11; OpenBSD i386) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1944.0 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.3319.102 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.2309.372 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.2117.157 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1866.237 Safari/537.36
Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.137 Safari/4E423F
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.116 Safari/537.36 Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B334b Safari/531.21.10
Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.517 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1664.3 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1664.3 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.16 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.17 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.62 Safari/537.36
Mozilla/5.0 (X11; CrOS i686 4319.74.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.57 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.2 Safari/537.36
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1468.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1467.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1500.55 Safari/537.36
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.90 Safari/537.36
Mozilla/5.0 (X11; NetBSD) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.116 Safari/537.36
Mozilla/5.0 (X11; CrOS i686 3912.101.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.116 Safari/537.36
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.60 Safari/537.17
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.15 (KHTML, like Gecko) Chrome/24.0.1295.0 Safari/537.15
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.14 (KHTML, like Gecko) Chrome/24.0.1292.0 Safari/537.14
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.13 (KHTML, like Gecko) Chrome/24.0.1290.1 Safari/537.13
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.13 (KHTML, like Gecko) Chrome/24.0.1290.1 Safari/537.13
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.13 (KHTML, like Gecko) Chrome/24.0.1290.1 Safari/537.13
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4) AppleWebKit/537.13 (KHTML, like Gecko) Chrome/24.0.1290.1 Safari/537.13
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.13 (KHTML, like Gecko) Chrome/24.0.1284.0 Safari/537.13
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.6 Safari/537.11
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.6 Safari/537.11
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.26 Safari/537.11
Mozilla/5.0 (Windows NT 6.0) yi; AppleWebKit/345667.12221 (KHTML, like Gecko) Chrome/23.0.1271.26 Safari/453667.1221
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.17 Safari/537.11
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_0) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.79 Safari/537.4
Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.2 (KHTML, like Gecko) Chrome/22.0.1216.0 Safari/537.2
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1
Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6
Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6
Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1
Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5
Mozilla/5.0 (X11; FreeBSD amd64) AppleWebKit/536.5 (KHTML like Gecko) Chrome/19.0.1084.56 Safari/1EA69
Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5
Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3
Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3"""

agentlist = agentlist.split('\n')

for i in range(50):
    print(get_ray('https://header.the-examples-book.com', agentlist[i]))
# Out:
# 79ec7ef16ae92007-IND
# 79ec7ef22a4e20b5-IND
# 79ec7efd5cf02007-IND
# 79ec7f091c7320e5-IND
# 79ec7f14c829206d-IND
# 79ec7f1f3d3d20b5-IND
# 79ec7f29ec1f20cd-IND
# 79ec7f357f502037-IND
# 79ec7f35dd821fef-IND
# 79ec7f363ef320cd-IND
# 79ec7f410bc62085-IND
# 79ec7f4c7c702007-IND
# 79ec7f578f392085-IND
# 79ec7f614b6420e5-IND
# 79ec7f6c49fb20fd-IND
# 79ec7f771c1520fd-IND
# 79ec7f77790320b5-IND
# 79ec7f81e895209d-IND
# 79ec7f8b8ba6209d-IND
# 79ec7f8be96ca631-IND
# 79ec7f95fa0f2085-IND
# 79ec7fa0ed4a2007-IND
# 79ec7fac4b8620b5-IND
# 79ec7fac9fa720e5-IND
# 79ec7facebc9209d-IND
# 79ec7fad4ca31fef-IND
# 79ec7fb8199e20e5-IND
# 79ec7fc2fa872007-IND
# 79ec7fcdba4d20b5-IND
# 79ec7fd74f132037-IND
# 79ec7fd79d55209d-IND
# 79ec7fd7feea20e5-IND
# 79ec7fd84da0209d-IND
# 79ec7fe1fad9206d-IND
# 79ec7fed59eb1fef-IND
# 79ec7ff8aadd20b5-IND
# 79ec7ff8faf520b5-IND
# 79ec800439d4206d-IND
# 79ec800488ad20cd-IND
# 79ec800fdd082055-IND
# 79ec8019fc1120fd-IND
# 79ec801a5e3b2037-IND
# 79ec8025690a2055-IND
# 79ec802e3fd420fd-IND
# 79ec8037486fa63d-IND
# 79ec8037aa04a60d-IND
# 79ec8041d8cda625-IND
# 79ec804d0b1120b5-IND
# 79ec805818e32007-IND
# 79ec80587ce820e5-IND

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
import lxml.html

def get_proxies():
    url = "https://www.sslproxies.org/"
    resp = requests.get(url)
    root = lxml.html.fromstring(resp.text)
    trs = root.xpath("//div[contains(@class, 'fpl-list')]//table//tr")
    proxies_aux = []
    for e in trs[1:]:
        ip = e.xpath(".//td")[0].text
        port = e.xpath(".//td")[1].text
        proxies_aux.append(f"{ip}:{port}")

    proxies = []
    for proxy in proxies_aux[:25]:
        proxies.append({'http': f'http://{proxy}', 'https': f'http://{proxy}'})

    return proxies

p = get_proxies()
resp = requests.get("https://ip.the-examples-book.com", proxies=p[0], verify=False, headers={'User-Agent': f"{agentlist[0]}"}, timeout=15)
print(resp.text)

def get_ray_proxy(header, proxy):
    response = requests.get("https://ip.the-examples-book.com", proxies=p[0], 
                            verify=False, headers={'User-Agent': f"{header}"}, timeout=15)

    content = str(bs4.BeautifulSoup(response.text, 'html.parser'))

    split = content.split(': ')

    # find CF-RAY in the content
    for i in range(len(split)):
        if "Cf-Ray".lower() in split[i].lower():
            return split[i+1][:20]


for i in range(50):
    print(get_ray('https://header.the-examples-book.com', agentlist[i]))
# Out:
# /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '204.2.218.145'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Hostname: 7f28e542b655
# IP: 127.0.0.1
# IP: 172.17.0.6
# RemoteAddr: 172.17.0.1:42112
# GET / HTTP/1.1
# Host: ip.the-examples-book.com
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36
# Accept: */*
# Accept-Encoding: gzip
# Cdn-Loop: cloudflare
# Cf-Connecting-Ip: 204.2.218.145
# Cf-Ipcountry: US
# Cf-Ray: 79ec8488b854ad5c-ATL
# Cf-Visitor: {"scheme":"https"}
# X-Forwarded-For: 204.2.218.145
# X-Forwarded-Host: ip.the-examples-book.com
# X-Forwarded-Proto: https
# X-Real-Ip: 204.2.218.145
#
#
# 79ec84949a6c20cd-IND
# 79ec8494feba209d-IND
# 79ec849e6f4620fd-IND
# 79ec84a85e8e2055-IND
# 79ec84b18ce71fef-IND
# 79ec84b1ec692085-IND
# 79ec84bbd9d92007-IND
# 79ec84d22eb3a607-IND
# 79ec84dcecbc20fd-IND
# 79ec84dd4c5f2085-IND
# 79ec84dd99792037-IND
# 79ec84ddfb5220b5-IND
# 79ec84de5916209d-IND
# 79ec84e84a51206d-IND
# 79ec84f29db82007-IND
# 79ec84f2fa541fef-IND
# 79ec84f3490220e5-IND
# 79ec84f3a99d2055-IND
# 79ec84f3f9ba2055-IND
# 79ec84fe6ad120e5-IND
# 79ec85096f7d1fef-IND
# 79ec8509caef2007-IND
# 79ec850a2b022007-IND
# 79ec85133eed20b5-IND
# 79ec851b5e892007-IND
# 79ec851ba99a20b5-IND
# 79ec851bfe472037-IND
# 79ec851c5bad1fef-IND
# 79ec851cacd3206d-IND
# 79ec8524ba37209d-IND
# 79ec85251a6d20e5-IND
# 79ec85257fba2085-IND
# 79ec8525d8eaa60d-IND
# 79ec852dfa152007-IND
# 79ec85375f34a63d-IND
# 79ec8537a9ec1fef-IND
# 79ec854218c920b5-IND
# 79ec854c68492007-IND
# 79ec8555ac94209d-IND
# 79ec855dacaf206d-IND
# 79ec855e092720cd-IND
# 79ec85670cbe2055-IND
# 79ec856fcb8720e5-IND
# 79ec85793a2e206d-IND
# 79ec8583fdcb2037-IND
# 79ec858459811fef-IND
# 79ec8584aeec20e5-IND
# 79ec858f0ce82007-IND
# 79ec85983b9020fd-IND
# 79ec8598ae512007-IND

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
import backoff

@backoff.on_exception(backoff.expo, requests.exceptions.RequestException, max_tries=8)
def get_ray(url, header):
    response = requests.get(url, 
        headers={'User-Agent': header, 
            'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
    )

    content = str(bs4.BeautifulSoup(response.text, 'html.parser'))

    split = content.split(': ')

    # find CF-RAY in the content
    for i in range(len(split)):
        if "Cf-Ray".lower() in split[i].lower():
            return split[i+1][:20]
        
for i in range(50):
    print(get_ray('https://static.the-examples-book.com', agentlist[i]))
# Out:
# 79ec8b711dbc2037-IND
# 79ec8b78ace22007-IND
# 79ec8b810ac820fd-IND
# 79ec8b8159652037-IND
# 79ec8b81bae82055-IND
# 79ec8b821f1c206d-IND
# 79ec8b8c983820e5-IND
# 79ec8b8cf8e71fef-IND
# 79ec8b8d4984a63d-IND
# 79ec8b8da87620e5-IND
# 79ec8b972f7b2055-IND
# 79ec8ba18ca7a631-IND
# 79ec8babde9c1fef-IND
# 79ec8bb5fd4e20cd-IND
# 79ec8bb64e4d2055-IND
# 79ec8bb6a9a62085-IND
# 79ec8bb6fd7e20cd-IND
# 79ec8bbfd86e20fd-IND
# 79ec8bc7ad94a631-IND
# 79ec8bc7f98f206d-IND
# 79ec8bcf9bbc20fd-IND
# 79ec8bcfeb6420cd-IND
# 79ec8bd70c5f206d-IND
# 79ec8bdfae1520cd-IND
# 79ec8bea083420cd-IND
# 79ec8bea682c209d-IND
# 79ec8bf4ee4c2007-IND
# 79ec8bf54adda61f-IND
# 79ec8bff3c2020cd-IND
# 79ec8bff88e82037-IND
# 79ec8bffe8dd2055-IND
# 79ec8c003d3c20e5-IND
# 79ec8c099aaa2055-IND
# 79ec8c12dbed1fef-IND
# 79ec8c1c5ba4a61f-IND
# 79ec8c1ca93e20e5-IND
# 79ec8c1d094920e5-IND
# 79ec8c1d6bdd20b5-IND
# 79ec8c1db9e9209d-IND
# 79ec8c27fa4a2055-IND
# 79ec8c3208c51fef-IND
# 79ec8c325aef2037-IND
# 79ec8c3b0c942037-IND
# 79ec8c3b58152085-IND
# 79ec8c43af8a20e5-IND
# 79ec8c43fb122007-IND
# 79ec8c4d49c420e5-IND
# 79ec8c4da9d320e5-IND
# 79ec8c578eb120cd-IND
# 79ec8c57d8161fef-IND

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
# write another function that finds the max number of requests per second the server can respond to
import time

def get_max(url, header):
    start = time.time()
    for i in range(100):
        response = requests.get(url, 
            headers={'User-Agent': header, 
                'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
        )
    end = time.time()
    return 100/(end-start)

for i in range(15):
    print(get_max('https://static.the-examples-book.com', agentlist[i]))
# Out:
# 17.85334949297651
# 18.985909936085854
# 18.76449540564901
# 19.31341147837087
# 19.278298378207744
# 19.3229826349469
# 18.91714799516218
# 19.360187114601416
# 4.811492967802616
# 19.283383213325884
# 19.22142025734947
# 19.357930954240366
# 19.393655127846664

# %%
times = [17.85334949297651,
18.985909936085854,
18.76449540564901,
19.31341147837087,
19.278298378207744,
19.3229826349469,
18.91714799516218,
19.360187114601416,
4.811492967802616,
19.283383213325884,
19.22142025734947,
19.357930954240366,
19.393655127846664]

print("AVG: ", sum(times)/len(times))
# Out:
# AVG:  17.989512688966578

# %% [markdown]
# This is the average requests per second the server can respond to.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
